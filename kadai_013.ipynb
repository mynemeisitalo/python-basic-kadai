# %%
purchased = True

def Total(price, tax):
  X = tax / 100
  Sum = price + price * X
  print(Sum)


def is_purchased():
    if (purchased):
        return True
    else:
        return False

if(is_purchased()):
  Total(500, 10)
# Out:
# 550.0
