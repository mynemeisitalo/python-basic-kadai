# %%
"""
上辺：10cm
下辺：20cm
高さ：5cm

公式：台形の面積 =（上辺＋下辺）× 高さ ÷ 2
"""
top_side = 10
bottom_side = 20
height = 5

print( (top_side + bottom_side) * height + "cm" )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-ca935f6da6d5> in <cell line: 12>()
#      10 height = 5
#      11
# ---> 12 print( (top_side + bottom_side) * height + "cm" )
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
"""
上辺：10cm
下辺：20cm
高さ：5cm

公式：台形の面積 =（上辺＋下辺）× 高さ ÷ 2
"""
top_side = 10
bottom_side = 20
height = 5

print( str((top_side + bottom_side) * height / 2 ) + "cm²" )
# Out:
# 75.0cm²

# %%
"""
上辺：10cm
下辺：20cm
高さ：5cm

公式：台形の面積 =（上辺＋下辺）× 高さ ÷ 2
"""
top_side = 10
bottom_side = 20
height = 5

area = (top_side + bottom_side) * height / 2

print( str(area) + "cm²" )
# Out:
# 75.0cm²
