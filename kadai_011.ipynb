# %%
array = ["水","金","地","火","木","土","天","海","冥"]

for a in array:
  print(a)

c = 0
while c != 9:
  print(array[c])
  c = c + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
