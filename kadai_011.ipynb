# %%
array = ["水","金","地","火","木","土","天","海","冥"]

for a in array:
  print(a)
  if a == "冥":
    for b in array:
      print(b)

print("-------------------")

c = 0
d = 0

while c != 9:
  print(array[c])
  c = c + 1
  if c == 9:
    while d != 9:
      print(array[d])
      d = d + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# -------------------
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
